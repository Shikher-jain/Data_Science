# %% [markdown]
# <a href="https://colab.research.google.com/github/Shikher-jain/Data_Science/blob/main/DL/PYTORCH/CampusX_PT/Pytorch_CampusX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
print(torch.__version__)

# %%
print(torch.cuda.is_available())

# %%
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
else:
    print("No GPU available")

# %%
torch.empty(2, 3)

# %%
torch.zeros(2, 3)

# %%
torch.ones(2, 3)

# %%
torch.rand(2, 3)

# %%
torch.manual_seed(101)
torch.rand(2, 3)

# %%
torch.tensor([[1, 2, 3], [4, 5, 6]])

# %%
print(torch.arange(1,11,2))
print(torch.linspace(1,10,4))
print(torch.eye(6))
print(torch.full((2,3),2.4))

# %%
x = torch.tensor([[1,2,3],[4,5,6]])
x.shape

# %%
torch.zeros_like(x)

# %%
torch.ones_like(x)

# %%
y = torch.tensor([[1,2,3],[4,5,6]],dtype=torch.float64)
y.shape,y.dtype

# %%
y.to((torch.int32))
x.dtype,y.dtype

# %%
x.dtype,y.dtype

# %%
torch.rand_like(x,dtype=torch.float64)

# %%
torch.cat((x,x,x), dim=0)

# %%
print("X :" ,x)
print("Y :" ,y)

print("ADD")
print(x+y)
print(torch.add(x,y))
print(x.add(y))

print("SUBTRACT")
print(x-y)
print(torch.sub(x,y))
print(x.sub(y))

print("MULTIPLY")
print(x*y)
print(torch.mul(x,y))
print(x.mul(y))

print("DIVIDE")
print(x/y)
print(torch.div(x,y))
print(x.div(y))

print("POWER")
print(x**y)
print(torch.pow(x,y))
print(x.pow(y))

print("SQRT")
print(torch.sqrt(x))
print(x.sqrt())

print("EXP")
print(torch.exp(x))
print(x.exp())

print("LOG")
print(torch.log(x))
print(x.log())

print("SIN")
print(torch.sin(x))
print(x.sin())

print("COS")
print(torch.cos(x))
print(x.cos())

print("TAN")
print(torch.tan(x))
print(x.tan())

print("ABS")
print(torch.abs(x))
print(x.abs())

print("SUM")
print(torch.sum(x))
print(x.sum())

print("MEAN")
print(torch.mean(y))
print(y.mean())

print("MAX")
print(torch.max(x))
print(x.max())

print("MIN")
print(torch.min(x))
print(x.min())

print("ARGMAX")
print(torch.argmax(x))
print(x.argmax())

print("ARGMIN")
print(torch.argmin(x))
print(x.argmin())

print("EQUAL")
print(torch.eq(x,y))
print(x.eq(y))

print("NOT EQUAL")
print(torch.ne(x,y))
print(x.ne(y))

print("Std")
print(torch.std(y))
print(y.std())

print("Var")
print(torch.var(y))
print(y.var())

print("Transpose")
print(torch.t(x))
print(x.t())

print("Transpose")
print(torch.transpose(x,0,1))
print(x.transpose(0,1))

print("Reshape")
print(torch.reshape(x,(3,2)))
print(x.reshape(3,2))

print("Reshape")
print(torch.reshape(x,(6,1)))
print(x.reshape(6,1))

print("Reshape")
print(torch.reshape(x,(1,6)))
print(x.reshape(1,6))


print('dot')
print(torch.dot(x[0],x[1]))
print(x[0].dot(x[1]))

# %%
print("Sigmoid")
x,torch.sigmoid(x)

# %%
print("ReLU")
x,torch.relu(x)

# %%
print("Softmax")
x =x.to(torch.float64)
x, torch.softmax(x, dim=0), torch.softmax(x, dim=1)

# %% [markdown]
# # ====================

# %%
x = torch.tensor(3.0, requires_grad=True)
y = x ** 2
y.backward()
x.grad
x , y

# %%
x = torch.tensor(3.0, requires_grad=True)
y = x ** 2
z = torch.sin(y)
# y.backward()
z.backward()
x.grad, y.grad, z.grad
# x , y , z

# %% [markdown]
# # ================

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
w,y,w,b

# %%
z = w*x+b
y_pred = torch.sigmoid(z)
loss = -(y*torch.log(y_pred) + (1-y)*torch.log(1-y_pred))

# %%
z,y_pred,loss

# %%
loss.backward()

# %%
w.grad, b.grad

# %% [markdown]
# # ===============

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)
y = x**2
# y.backward()
x.grad

# %%
x = torch.tensor([1.0,2.0,3.0], requires_grad=True)
y1 = (x**2).mean()
y1.backward()
x.grad,x.grad.zero_

# %% [markdown]
# # =======training pipeline

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv')
df.head()

# %%
df.shape

# %%
df.drop(columns=['id', 'Unnamed: 32'], inplace= True)

# %%
df.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 1:], df.iloc[:, 0], test_size=0.2)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train

# %%
y_train

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %%
y_train

# %%
X_train_tensor = torch.from_numpy(X_train)
X_test_tensor = torch.from_numpy(X_test)
y_train_tensor = torch.from_numpy(y_train)
y_test_tensor = torch.from_numpy(y_test)

# %%
X_train_tensor.shape

# %%
y_train_tensor.shape

# %%
class MySimpleNN():

  def __init__(self, X):

    self.weights = torch.rand(X.shape[1], 1, dtype=torch.float64, requires_grad=True)
    self.bias = torch.zeros(1, dtype=torch.float64, requires_grad=True)

  def forward(self, X):
    z = torch.matmul(X, self.weights) + self.bias
    y_pred = torch.sigmoid(z)
    return y_pred

  def loss_function(self, y_pred, y):
    # Clamp predictions to avoid log(0)
    epsilon = 1e-7
    y_pred = torch.clamp(y_pred, epsilon, 1 - epsilon)

    # Calculate loss
    loss = -(y_train_tensor * torch.log(y_pred) + (1 - y_train_tensor) * torch.log(1 - y_pred)).mean()
    return loss

# %%
learning_rate = 0.1
epochs = 25

# %%
# create model
model = MySimpleNN(X_train_tensor)

# define loop
for epoch in range(epochs):

  # forward pass
  y_pred = model.forward(X_train_tensor)

  # loss calculate
  loss = model.loss_function(y_pred, y_train_tensor)

  # backward pass
  loss.backward()

  # parameters update
  with torch.no_grad():
    model.weights -= learning_rate * model.weights.grad
    model.bias -= learning_rate * model.bias.grad

  # zero gradients
  model.weights.grad.zero_()
  model.bias.grad.zero_()

  # print loss in each epoch
  print(f'Epoch: {epoch + 1}, Loss: {loss.item()}')

# %%
model.bias

# %%
# model evaluation
with torch.no_grad():
  y_pred = model.forward(X_test_tensor)
  y_pred = (y_pred > 0.9).float()
  accuracy = (y_pred == y_test_tensor).float().mean()
  print(f'Accuracy: {accuracy.item()}')

# %% [markdown]
# # Update NN using nn module

# %%
import torch.nn as nn

# %%
class Model(nn.Module):

  def __init__(self, num_features):
    super(Model, self).__init__()
    self.linear = nn.Linear(num_features, 1)
    self.sigmoid = nn.Sigmoid()

  def forward(self, features):
    out = self.linear(features)
    out = self.sigmoid(out)
    return out

# %%
features = torch.rand(10, 5)

model = Model(features.shape[1])
model(features)

# %%
model.linear , model.linear.weight , model.linear.bias

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

summary(model, input_size=features.shape)

# %%
class Model2(nn.Module):

  def __init__(self, num_features):
    super(Model2, self).__init__()
    self.linear1 = nn.Linear(num_features, 3)
    self.relu = nn.ReLU()

    self.linear2 = nn.Linear(3, 1)
    self.sigmoid = nn.Sigmoid()

  def forward(self, features):
    out = self.linear1(features)
    out = self.relu(out)
    out = self.linear2(out)
    out = self.sigmoid(out)
    return out

# %%
features2 = torch.rand(10, 5)

model2 = Model2(features.shape[1])
model2(features2)

# %%
print(model2.linear1 , model2.linear1.weight , model2.linear1.bias)
print(model2.linear2 , model2.linear2.weight , model2.linear2.bias)

# %%
summary(model2, input_size=features2.shape)

# %% [markdown]
# # using sequencial

# %%
class Model3(nn.Module):

  def __init__(self, num_features):
    super(Model3, self).__init__()
    self.network = nn.Sequential(
        nn.Linear(num_features, 3),
        nn.ReLU(),
        nn.Linear(3, 1),
        nn.Sigmoid()
    )

  def forward(self, features):
    out = self.network(features)
    return out

features3 = torch.rand(10, 5)

model3 = Model3(features.shape[1])
model3(features3)

summary(model3, input_size=features3.shape)

# %% [markdown]
# # Updation usind nn on prev Manual NN

# %%
class MySimpleNN(nn.Module):

  def __init__(self, num_features):
    super(MySimpleNN, self).__init__()
    self.linear = nn.Linear(num_features, 1)
    self.sigmoid = nn.Sigmoid()


  def forward(self, features):
    out = self.linear(features)
    out = self.sigmoid(out)
    return out

# %%
learning_rate = 0.1
epochs = 25

# %%
loss_function = nn.BCELoss()

# %%
# create model
model4 = MySimpleNN(X_train_tensor.shape[1])

optimizer = torch.optim.SGD(model4.parameters(), lr=learning_rate)

y_train_tensor = y_train_tensor.float()
X_train_tensor = X_train_tensor.float()
X_test_tensor = X_train_tensor.float()
# define loop
for epoch in range(epochs):

  # forward pass
  y_pred = model4(X_train_tensor)

  # loss calculate
  loss = loss_function(y_pred, y_train_tensor.view(-1,1))

  # zero gradients
  optimizer.zero_grad()

  # backward pass
  loss.backward()

  # parameters update
  optimizer.step()


  # print loss in each epoch
  print(f'Epoch: {epoch + 1}, Loss: {loss.item()}')
# Out:
# Epoch: 1, Loss: 0.6698242425918579
# Epoch: 2, Loss: 0.5166855454444885
# Epoch: 3, Loss: 0.4354337453842163
# Epoch: 4, Loss: 0.38474053144454956
# Epoch: 5, Loss: 0.3493507504463196
# Epoch: 6, Loss: 0.32282593846321106
# Epoch: 7, Loss: 0.3019726574420929
# Epoch: 8, Loss: 0.28500840067863464
# Epoch: 9, Loss: 0.2708500325679779
# Epoch: 10, Loss: 0.2587963938713074
# Epoch: 11, Loss: 0.24837081134319305
# Epoch: 12, Loss: 0.23923607170581818
# Epoch: 13, Loss: 0.23114602267742157
# Epoch: 14, Loss: 0.22391606867313385
# Epoch: 15, Loss: 0.2174045592546463
# Epoch: 16, Loss: 0.21150065958499908
# Epoch: 17, Loss: 0.20611628890037537
# Epoch: 18, Loss: 0.20118027925491333
# Epoch: 19, Loss: 0.19663438200950623
# Epoch: 20, Loss: 0.1924304962158203
# Epoch: 21, Loss: 0.18852844834327698
# Epoch: 22, Loss: 0.18489427864551544
# Epoch: 23, Loss: 0.18149922788143158
# Epoch: 24, Loss: 0.178318589925766
# Epoch: 25, Loss: 0.17533104121685028

# %%
model4.linear.bias

# %%
# model evaluation
with torch.no_grad():
  y_pred = model4(X_test_tensor)
  y_pred = (y_pred > 0.9).float()
  accuracy = (y_pred == y_test_tensor).float().mean()
  print(f'Accuracy: {accuracy.item()}')
# Out:
# Accuracy: 0.577019453048706
