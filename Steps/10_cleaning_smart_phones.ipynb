# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv('smartphone_cleaned_v2.csv')
df.head()

# %%
df.isnull().sum()

# %%
df['brand_name'].value_counts().head().plot(kind='bar')

# %%
df['price'].describe()

# %%
sns.histplot(df['price'], kde=True)

# %%
df.price.skew()

# %%
sns.boxplot(df[df['price']<200000]['price'])

# %%
df[df['price']<200000]

# %%
df.price.isnull().sum()

# %%
df.rating.describe()

# %%
sns.histplot(df['rating'], kde=True)

# %%
df.rating.skew()

# %%
sns.boxplot(x=df['rating'])

# %%
df.rating.isnull().sum()

# %%
df.rating = df.rating.fillna(df.rating.mean())

# %%
df.processor_brand.isnull().sum()

# %%
df.processor_brand.value_counts()

# %%
df.processor_brand.fillna("Unknown", inplace=True)
df.processor_name.fillna("Unknown", inplace=True)

# %%
df.nums_cores.isnull().sum()

# %%
df[df.nums_cores.isnull()]

# %%
df.nums_cores.fillna('Hexa Core', inplace=True)
df.loc[425]['nums_cores'] = 'Octa Core'

# %%
df['processor_speed'].isnull().sum()

# %%
df[~df['processor_speed'].isnull()]

# %%
df[df['processor_speed'].isnull()]

# %%
# df['processor_speed'].fillna(, inplace=True)
# df['processor_speed'].fillna(, inplace=True)
df['processor_speed']=df['processor_speed'].str.replace('GHz Processor', '', regex=False).str.strip()
df['processor_speed'].describe()
df['processor_speed']=df['processor_speed'].astype(float)

# %%
df['processor_speed'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='processor_speed'>

# %%
df['processor_speed'].describe()
# df['processor_speed'].mean()

# %%
df['processor_speed'].fillna(np.random.uniform(df['processor_speed'].min(),df['processor_speed'].max()), inplace=True)

# %%
df["battery_capacity"].isnull().sum()
# Out:
# np.int64(11)

# %%
df["battery_capacity"].describe()
df["battery_capacity"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 980 entries, 0 to 979
# Series name: battery_capacity
# Non-Null Count  Dtype
# --------------  -----
# 969 non-null    float64
# dtypes: float64(1)
# memory usage: 7.8 KB

# %%
df["battery_capacity"].skew()
# Out:
# np.float64(9.260986328291182)

# %%
df["battery_capacity"].plot(kind='box')
# Out:
# <Axes: >

# %%
df["battery_capacity"].median()
# Out:
# np.float64(5000.0)

# %%
df["battery_capacity"].fillna(df["battery_capacity"].median(), inplace=True)

# %%
df['primary_camera_front'].isnull().sum()
# Out:
# np.int64(28)

# %%
df['primary_camera_front'].fillna(-1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            980 non-null    object
#  1   model                 980 non-null    object
#  2   price                 980 non-null    int64
#  3   rating                980 non-null    float64
#  4   has_volte             980 non-null    bool
#  5   has_wifi              980 non-null    bool
#  6   has_ir                980 non-null    bool
#  7   has_nfc               980 non-null    bool
#  8   processor_brand       980 non-null    object
#  9   processor_name        980 non-null    object
#  10  nums_cores            980 non-null    object
#  11  processor_speed       980 non-null    float64
#  12  has_5g                980 non-null    bool
#  13  sim_type              980 non-null    object
#  14  ram_capacity          980 non-null    float64
# ...

# %%
df.to_csv('smartphone_cleaned_v3.csv', index=False)
